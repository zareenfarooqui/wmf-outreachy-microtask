# %% [markdown]
# ## Wikimedia Foundation - Outreachy Microtask

# %% [markdown]
# This notebook was created as a microtask for the [Gnome Outreachy internship program](https://wiki.gnome.org/Outreachy).
#
#
# The Wikipedia dataset can be downloaded [here](https://lists.wikimedia.org/pipermail/wiki-research-l/2016-April/005129.html).
#
# Please have at least 2 GB of free RAM to run this notebook.

# %% [markdown]
# #### Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### Create DataFrame

# %%
#Note: you may need to change to an absolute path if the dataset is not in the same folder
enwiki_DF = pd.read_csv("enwiki_20160204_headings.tsv", header=0, sep='\t', error_bad_lines=False)
# Out:
# Skipping line 23763217: expected 4 fields, saw 6

# %% [markdown]
# #### Explore DataFrame

# %%
enwiki_DF.head()
# Out:
#    page_id                          page_title  heading_level  \
# 0  2336433                      Helena Carroll              2
# 1  3046517  Articles for deletion/Domotic maid              3
# 2  2336433                      Helena Carroll              2
# 3  3046518             2005Oct31 Hydnjo ns.png              2
# 4  2336433                      Helena Carroll              2
#
#        heading_text
# 0             Death
# 1  [[Domotic maid]]
# 2        References
# 3          Summary
# 4    External links

# %%
enwiki_DF.count()
# Out:
# page_id          27618485
# page_title       27618475
# heading_level    27618485
# heading_text     27618477
# dtype: int64

# %% [markdown]
# Count returns different values for columns, so there are null values in `page_title` and `heading_text`.
#
# The articles below are titles "NaN" (not actually null).

# %%
enwiki_DF[(enwiki_DF['page_title'].isnull() == True)]
# Out:
#          page_id page_title  heading_level                 heading_text
# 7675588    49244        NaN              2              Floating point
# 7675591    49244        NaN              3   Operations generating NaN
# 7675599    49244        NaN              3                   Quiet NaN
# 7675603    49244        NaN              3               Signaling NaN
# 7675605    49244        NaN              2         Function definition
# 7675612    49244        NaN              2                 Integer NaN
# 7675633    49244        NaN              2                     Display
# 7675636    49244        NaN              2                    Encoding
# 7675641    49244        NaN              2                  References
# 7675646    49244        NaN              2              External links

# %%
enwiki_DF[(enwiki_DF['heading_text'].isnull() == True)]
# Out:
#            page_id                                       page_title  \
# 1515667    2679835  Cthulhu Mythos reference codes and bibliography
# 5227156   11962867                         Glossary of baseball (N)
# 5330301    8717998                                        MG N-type
# 22533740  45286225                               Chembox/testcases6
# 24065464    964702                                   Mazda C engine
# 24547466   1051265                                 Mazda N platform
# 26257538   1657544                              List of acronyms: N
# 27603282  49265090                   List of television programs: N
#
#           heading_level heading_text
# 1515667               4          NaN
# 5227156               3          NaN
# 5330301               2          NaN
# 22533740              4          NaN
# 24065464              2          NaN
# 24547466              2          NaN
# 26257538              2          NaN
# 27603282              3          NaN

# %%
enwiki_DF.dtypes
# Out:
# page_id           int64
# page_title       object
# heading_level     int64
# heading_text     object
# dtype: object

# %%
len(enwiki_DF['page_title'].unique())
# Out:
# 6357824

# %%
len(enwiki_DF['page_id'].unique())
# Out:
# 6364745

# %% [markdown]
# In April 2016, Wikipedia had ~5.1 million articles, so out of the 6.3 million page_ids, about 1.2 million of the page_ids must be referring to non-articles (other namespaces).

# %% [markdown]
# #### Generate list of 100 most frequent section titles

# %%
#commented out this line of code to reduce size of notebook

#enwiki_DF.groupby('heading_text').size()

# %% [markdown]
# That doesn't work.
#
# Instead, create a new column to remove leading and trailing whitespace from `heading_text`

# %%
enwiki_DF['heading_text_noWS'] = pd.core.strings.str_strip(enwiki_DF['heading_text'])

# %%
enwiki_DF.head()
# Out:
#    page_id                          page_title  heading_level  \
# 0  2336433                      Helena Carroll              2
# 1  3046517  Articles for deletion/Domotic maid              3
# 2  2336433                      Helena Carroll              2
# 3  3046518             2005Oct31 Hydnjo ns.png              2
# 4  2336433                      Helena Carroll              2
#
#        heading_text heading_text_noWS
# 0             Death             Death
# 1  [[Domotic maid]]  [[Domotic maid]]
# 2        References        References
# 3          Summary            Summary
# 4    External links    External links

# %%
section_titles = enwiki_DF.groupby('heading_text_noWS').size().sort_values(ascending=False)

# %%
section_titles[:5]
# Out:
# heading_text_noWS
# References        3933510
# External links    2249554
# See also          1114379
# Summary            732295
# Licensing          695887
# dtype: int64

# %%
mostFrequentTitles_DF = pd.DataFrame({'section_title':section_titles.index, 'frequency':section_titles.values})

# %%
mostFrequentTitles_DF.head(100)
# Out:
#     frequency                                      section_title
# 0     3933510                                         References
# 1     2249554                                     External links
# 2     1114379                                           See also
# 3      732295                                            Summary
# 4      695887                                          Licensing
# 5      509498                                            History
# 6      276974                                              Notes
# 7      162768                                             Career
# 8      144400                                          Biography
# 9      141217                                      Track listing
# 10     137631                                    Further reading
# 11     137035                                            Sources
# 12     111723                                       Bibliography
# 13     105465                                         Licensing:
# 14     103177                                          Geography
# 15     102048                                               Cast
# 16     101171                                         Early life
# 17      96112                                              Links
# 18      95009                                              Users
# 19      90384                                         Background
# 20      89379                                               Plot
# 21      89003                                      Personal life
# 22      80724                                          Reception
# 23      78673                                        Description
# 24      76854                                        Discography
# 25      76182                                       Demographics
# 26      75327                                             Awards
# 27      72011                                          Personnel
# 28      69550                                           Assessed
# 29      67931                                          Additions
# 30      61171                                            Results
# 31      60067                                          Education
# 32      54906                                         Reassessed
# 33      52637                                        Filmography
# 34      48354                                               Life
# 35      48223                                            Honours
# 36      45873                                         Production
# 37      45286                                              Works
# 38      42110                                            Gallery
# 39      38216                                           Overview
# 40      37731                                            Singles
# 41      36731                                         Discussion
# 42      36433                                          Footnotes
# 43      33370                                              Death
# 44      31548                                             Charts
# 45      31409                                       Distribution
# 46      29230                                         Population
# 47      28422                                       Publications
# 48      27651                                             Family
# 49      27532                                             Legacy
# 50      26709                                              Entry
# 51      26542                                 Selected additions
# 52      26297                                              Final
# 53      26037                                             Events
# 54      25631                                              Music
# 55      25329                                            Species
# 56      25034                                              Usage
# 57      25006                                             Albums
# 58      24846                                              Books
# 59      24603                                         Television
# 60      24093                                        Club career
# 61      24084                                             Source
# 62      23870                                            Economy
# 63      23587                                        Early years
# 64      23384                                            Removed
# 65      23123                           Early life and education
# 66      22888                                 Critical reception
# 67      22465                               International career
# 68      22446                                           Schedule
# 69      22347                                           Location
# 70      21785                                Professional career
# 71      21327                               Notes and references
# 72      21068  <span style="font-size:150%">Clerk, CheckUser,...
# 73      21059  <span style="font-size:150%">Comments by other...
# 74      20745                                  Career statistics
# 75      20677                                     Notable people
# 76      20606                                           Synopsis
# 77      20173                                  Chart performance
# 78      19891                                              Other
# 79      19545                                          Etymology
# 80      19536                                     Playing career
# 81      18636                                            Climate
# 82      18441                                        Development
# 83      18001                                           Politics
# 84      17915                                   Political career
# 85      17830                                             Deaths
# 86      17817                                     Transportation
# 87      17434                                 Fair use rationale
# 88      17309                                             People
# 89      17117                                          Aftermath
# 90      17002                                    Life and career
# 91      16894                                               Film
# 92      16354                                             Births
# 93      16343                                            Release
# 94      16318                                       Early career
# 95      16254                                         Soundtrack
# 96      16223                                        Music video
# 97      16211                                            Members
# 98      15938                                               Club
# 99      15923                                     Regular season

# %%
#only run this cell if the dataframe did not display 100 rows
pd.options.display.max_rows = 100

# %% [markdown]
# ### Bonus Task

# %% [markdown]
# Generate the list of the 100 section titles that are used in the largest number of articles, each with the percentage of articles that contain such a section.

# %% [markdown]
# Assume page titles which contain "/" or "." are not articles and exclude them from analysis.

# %%
enwiki_articles_DF = enwiki_DF.copy()

# %%
enwiki_articles_DF.head()
# Out:
#    page_id                          page_title  heading_level  \
# 0  2336433                      Helena Carroll              2
# 1  3046517  Articles for deletion/Domotic maid              3
# 2  2336433                      Helena Carroll              2
# 3  3046518             2005Oct31 Hydnjo ns.png              2
# 4  2336433                      Helena Carroll              2
#
#        heading_text heading_text_noWS
# 0             Death             Death
# 1  [[Domotic maid]]  [[Domotic maid]]
# 2        References        References
# 3          Summary            Summary
# 4    External links    External links

# %%
enwiki_articles_DF = enwiki_articles_DF.drop('heading_text', 1)

# %%
enwiki_articles_DF.head()
# Out:
#    page_id                          page_title  heading_level  \
# 0  2336433                      Helena Carroll              2
# 1  3046517  Articles for deletion/Domotic maid              3
# 2  2336433                      Helena Carroll              2
# 3  3046518             2005Oct31 Hydnjo ns.png              2
# 4  2336433                      Helena Carroll              2
#
#   heading_text_noWS
# 0             Death
# 1  [[Domotic maid]]
# 2        References
# 3           Summary
# 4    External links

# %%
#maybe change this to only drop NaNs from page_title

enwiki_articles_DF.dropna(inplace=True)

# %%
enWikiArticlesOnly_DF = enwiki_articles_DF[~enwiki_articles_DF.page_title.str.contains("\.|\/")]

# %%
enWikiArticlesOnly_DF.count()
# Out:
# page_id              21937694
# page_title           21937694
# heading_level        21937694
# heading_text_noWS    21937694
# dtype: int64

# %%
len(enWikiArticlesOnly_DF['page_id'].unique())
# Out:
# 4631002

# %%
len(enWikiArticlesOnly_DF['page_title'].unique())
# Out:
# 4624341

# %% [markdown]
# Only 4.6 million unique page_ids left, so I'm losing 400-500K articles

# %%
#commented out this line of code to reduce size of notebook

#enwiki_articles_DF[~enwiki_articles_DF.page_title.str.contains("\.|\/")]

# %%
enWikiArticlesOnly_DF.head()
# Out:
#    page_id      page_title  heading_level heading_text_noWS
# 0  2336433  Helena Carroll              2             Death
# 2  2336433  Helena Carroll              2        References
# 4  2336433  Helena Carroll              2    External links
# 5  2336437  Mario Sammarco              2         Biography
# 6  2336437  Mario Sammarco              2        Recordings

# %%
header_freq = enWikiArticlesOnly_DF.groupby('heading_text_noWS').size().sort_values(ascending=False)

# %%
header_freq[:10]
# Out:
# heading_text_noWS
# References         3792066
# External links     2168509
# See also           1060642
# History             491924
# Notes               263258
# Career              152605
# Track listing       135144
# Further reading     132480
# Biography           130716
# Bibliography        106534
# dtype: int64

# %%
header_freq_percent_DF = pd.DataFrame({'header_title':header_freq.index, 'header_frequency':header_freq.values})

# %%
header_freq_percent_DF.head()
# Out:
#    header_frequency    header_title
# 0           3792066      References
# 1           2168509  External links
# 2           1060642        See also
# 3            491924         History
# 4            263258           Notes

# %%
header_freq_percent_DF['header_percent'] = (header_freq_percent_DF['header_frequency']/4624341)*100

# %%
header_freq_percent_DF.head(100)
# Out:
#     header_frequency              header_title  header_percent
